# %%
import json
from pandas import DataFrame

refundPolicy = '{"outbound":{"indexId":10,"refundPolicy":{"isValid":true,"errorCode":"","airlineCode":"IR","bookingClass":"Y","p1":30,"p2":30,"p3":60,"p4":60,"p5":60},"refundPolicy2":{"isValid":true,"errorCode":"","airlineCode":"IR","bookingClass":"Y","penaltyRules":[{"By":"5/2/2019 12:00:00 PM","Persian_By":" تا ساعت 12 روز پنج شنبه 12 اردیبهشت","Percent":30},{"Persian_By":" از ساعت 12 روز پنج شنبه 12 اردیبهشت به بعد ","Percent":60}]},"sessionId":"","transactionId":"","system":"G","dumped":true,"dumpRate":10.0,"cashBackEnabled":false,"airline":{"code":"IR","name":"ایران ایر"},"flightNumber":"","departure":"2019-05-03 19:10:00","arrival":"2019-05-03 20:40:00","cabin":{"type":"E","name":"اکونومی"},"status":"","reservationType":3,"charter":false,"refundMethod":3,"paxFareNumber":0,"itemNo":"14","totalPrice":{"amount":3506000.0,"cashBack":0,"currency":"IRR"},"originalPrice":3896000.0,"totalFare":{"amount":0.0,"cashBack":0,"currency":"IRR"},"totalTax":{"amount":0.0,"cashBack":0,"currency":"IRR"},"pricingDetails":[{"passengerType":"ADL","amount":3506000.0,"cashBack":0,"currency":"IRR"},{"passengerType":"CHD","amount":1789000.0,"cashBack":0,"currency":"IRR"},{"passengerType":"INF","amount":406000.0,"cashBack":0,"currency":"IRR"}],"miniRule":"","lastTicketDate":"","baggageFreeAllowanceDisplay":"","baggageFreeAllowance":0,"baggageQuantityCode":"","baggageUnitQualifier":"","legs":[{"index":0,"internalId":"53c40e55-1ce9-4437-8f03-9cee1c4365a5","reference":"0","numberOfStops":0,"airline":{"code":"IR","name":"ایران ایر"},"origin":{"iataCode":"THR"},"destination":{"iataCode":"MHD"},"durationInMinutes":0,"departAt":"2019-05-03 19:10:00","arriveAt":"2019-05-03 20:40:00","cabin":{"type":"E","name":"اکونومی"},"status":"9","statusTitle":"موجود","details":[{"internalId":"d28f1540-167e-4d4f-8d22-c631567c2006","id":"1840475","index":0,"origin":{"iataCode":"THR"},"destination":{"iataCode":"MHD"},"marketingCarrier":"IR","operatingCarrier":"IR","electronicTicketing":false,"flightNo":"468","departAt":"2019-05-03 19:10:00","departureTerminal":"2","arriveAt":"2019-05-03 20:40:00","arrivalTerminal":"","aircraft":"Fokker 100","description":"Gabriel","rph":"","duration":""}]}],"proposalId":"00000000-0000-0000-0000-000000000000","flightClass":"Y","agency":"7owrang"},"inbound":{"indexId":25,"refundPolicy":{"isValid":true,"errorCode":"","airlineCode":"IR","bookingClass":"Y","p1":30,"p2":30,"p3":60,"p4":60,"p5":60},"refundPolicy2":{"isValid":true,"errorCode":"","airlineCode":"IR","bookingClass":"Y","penaltyRules":[{"By":"5/5/2019 12:00:00 PM","Persian_By":" تا ساعت 12 روز یک شنبه 15 اردیبهشت","Percent":30},{"Persian_By":" از ساعت 12 روز یک شنبه 15 اردیبهشت به بعد ","Percent":60}]},"sessionId":"","transactionId":"","system":"G","dumped":true,"dumpRate":10.0,"cashBackEnabled":false,"airline":{"code":"IR","name":"ایران ایر"},"flightNumber":"","departure":"2019-05-06 17:45:00","arrival":"2019-05-06 19:15:00","cabin":{"type":"E","name":"اکونومی"},"status":"","reservationType":3,"charter":false,"refundMethod":3,"paxFareNumber":0,"itemNo":"14","totalPrice":{"amount":3506000.0,"cashBack":0,"currency":"IRR"},"originalPrice":3896000.0,"totalFare":{"amount":0.0,"cashBack":0,"currency":"IRR"},"totalTax":{"amount":0.0,"cashBack":0,"currency":"IRR"},"pricingDetails":[{"passengerType":"ADL","amount":3506000.0,"cashBack":0,"currency":"IRR"},{"passengerType":"CHD","amount":1789000.0,"cashBack":0,"currency":"IRR"},{"passengerType":"INF","amount":406000.0,"cashBack":0,"currency":"IRR"}],"miniRule":"","lastTicketDate":"","baggageFreeAllowanceDisplay":"","baggageFreeAllowance":0,"baggageQuantityCode":"","baggageUnitQualifier":"","legs":[{"index":0,"internalId":"9a843586-1991-474b-9a35-49bfd1251bd4","reference":"0","numberOfStops":0,"airline":{"code":"IR","name":"ایران ایر"},"origin":{"iataCode":"MHD"},"destination":{"iataCode":"THR"},"durationInMinutes":0,"departAt":"2019-05-06 17:45:00","arriveAt":"2019-05-06 19:15:00","cabin":{"type":"E","name":"اکونومی"},"status":"9","statusTitle":"موجود","details":[{"internalId":"d9eae245-a290-4256-99c1-85bab6b62488","id":"1840478","index":0,"origin":{"iataCode":"MHD"},"destination":{"iataCode":"THR"},"marketingCarrier":"IR","operatingCarrier":"IR","electronicTicketing":false,"flightNo":"467","departAt":"2019-05-06 17:45:00","departureTerminal":"","arriveAt":"2019-05-06 19:15:00","arrivalTerminal":"2","aircraft":"Airbus A320","description":"Gabriel","rph":"","duration":""}]}],"proposalId":"00000000-0000-0000-0000-000000000000","flightClass":"Y","agency":"7owrang"},"passengers":{"adults":1,"children":0,"infants":0},"contactInfo":{"name":"","email":"yoosefi12@gmail.com","phone":"09359936376","cellphone":"09359936376"},"searchId":5416237285026187019}'
js = json.loads(refundPolicy)


print json.dumps(js,indent = 4)
# Out:
# {
#     "inbound": {
#         "refundPolicy": {
#             "p2": 30,
#             "p3": 60,
#             "p1": 30,
#             "p4": 60,
#             "p5": 60,
#             "isValid": true,
#             "errorCode": "",
#             "airlineCode": "IR",
#             "bookingClass": "Y"
#         },
#         "status": "",
#         "charter": false,
#         "totalPrice": {
#             "currency": "IRR",
#             "amount": 3506000.0,
#             "cashBack": 0
#         },
#         "dumpRate": 10.0,
#         "cashBackEnabled": false,
#         "dumped": true,
#         "departure": "2019-05-06 17:45:00",
#         "refundPolicy2": {
#             "errorCode": "",
#             "isValid": true,
#             "airlineCode": "IR",
#             "bookingClass": "Y",
#             "penaltyRules": [
#                 {
# ...

# %%
from pandas import DataFrame

frame = DataFrame(js)

js2 = frame['outbound']['refundPolicy2']


for l in js2['penaltyRules']:
    text = l['Persian_By']
    percent = l['Percent']
    print text + ' - ' + str(percent) + '%'
# Out:
#  تا ساعت 12 روز پنج شنبه 12 اردیبهشت - 30%
#  از ساعت 12 روز پنج شنبه 12 اردیبهشت به بعد  - 60%
